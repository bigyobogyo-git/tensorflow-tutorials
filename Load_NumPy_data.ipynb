# %%
import numpy as np
import tensorflow as tf
# Out:
# 2025-11-21 16:34:21.837466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763739261.849043   89677 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763739261.852817   89677 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763739261.863264   89677 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763739261.863274   89677 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763739261.863276   89677 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763739261.863277   89677 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-21 16:34:21.866561: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
DATA_URL = 'https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz'

path = tf.keras.utils.get_file('mnist.npz', DATA_URL)
with np.load(path) as data:
  train_examples = data['x_train']
  train_labels = data['y_train']
  test_examples = data['x_test']
  test_labels = data['y_test']
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_examples, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_examples, test_labels))
# Out:
# I0000 00:00:1763739286.838158   89677 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8939 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:08:00.0, compute capability: 7.5

# %%
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

model.compile(optimizer=tf.keras.optimizers.RMSprop(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['sparse_categorical_accuracy'])
# Out:
# /home/xy/Desktop/ml/TF/tf_2.19.1/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.fit(train_dataset, epochs=10)
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763739314.157858   89812 service.cc:152] XLA service 0x7936bc005860 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763739314.157872   89812 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-11-21 16:35:14.174958: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1763739314.210821   89812 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 184/938 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - loss: 23.5673 - sparse_categorical_accuracy: 0.7007
# I0000 00:00:1763739314.527181   89812 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 3.6916 - sparse_categorical_accuracy: 0.8781
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 837us/step - loss: 0.5503 - sparse_categorical_accuracy: 0.9271
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 819us/step - loss: 0.3884 - sparse_categorical_accuracy: 0.9460
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 832us/step - loss: 0.3203 - sparse_categorical_accuracy: 0.9560
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 858us/step - loss: 0.2615 - sparse_categorical_accuracy: 0.9629
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 812us/step - loss: 0.2400 - sparse_categorical_accuracy: 0.9663
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 863us/step - loss: 0.2010 - sparse_categorical_accuracy: 0.9708
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 804us/step - loss: 0.1958 - sparse_categorical_accuracy: 0.9722
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 793us/step - loss: 0.1784 - sparse_categorical_accuracy: 0.9741
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 808us/step - loss: 0.1677 - sparse_categorical_accuracy: 0.9774

# %%
model.evaluate(test_dataset)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5948 - sparse_categorical_accuracy: 0.9564
# [0.5948231220245361, 0.9563999772071838]
